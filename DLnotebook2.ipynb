# %%
pip list
# Out:
# Package                                  Version
# ---------------------------------------- ---------------
# absl-py                                  2.1.0
# aiohttp                                  3.9.3
# aiohttp-cors                             0.7.0
# aiorwlock                                1.4.0
# aiosignal                                1.3.1
# annotated-types                          0.6.0
# anyio                                    3.7.1
# archspec                                 0.2.3
# argon2-cffi                              23.1.0
# argon2-cffi-bindings                     21.2.0
# arrow                                    1.3.0
# asttokens                                2.4.1
# async-timeout                            4.0.3
# attrs                                    23.2.0
# Babel                                    2.14.0
# beautifulsoup4                           4.12.3
# bleach                                   6.1.0
# blessed                                  1.20.0
# ...

# %%
import torch as nn

# %%
x  = nn.tensor([1, 2])
print(x)
# Out:
# tensor([1, 2])

# %%
y = nn.tensor([[[3, 4, 5],[5, 6, 7]], [[3, 4, 5],[5, 6, 7]]])
print(y)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 y = nn.tensor([[[3, 4, 5],[5, 6, 7]], [[3, 4, 5],[5, 6, 7]]])
#       2 print(y)
#
# NameError: name 'nn' is not defined
